# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
import bokeh

# %%
# You could use this, if you are a fan of xkcd's comic strips :)

#plt.xkcd()

# %% [markdown]
# # 03. Data Visualization. Exploratory Data Analysis
# ### Seeing what's inside our data… and allowing others to see
#
# Topics:
# * Analytical graphs: principles, creation, examples;
# * Plots: histograms, scatterplots, line plots, pie charts. Usages and examples;
# * Enhancing plots: colors, labels, formatting;
# * Telling the correct story;
# * Exploratory data analysis: motivation, principles, applications.

# %%
# Quick check
print('We are ready for action! :)')
# Out:
# We are ready for action! :)

# %% [markdown]
# ### Main Concepts in Data Visualization
# How to tell the right story

# %% [markdown]
# As human beings, we are amazingly good at spotting patterns (Trends over time, correlations, comparisons, ranges, etc.), so vizualizing data helps us understand the information better. By plotting different views on the data we can help ourselves explore and understand it, as well as convey the stories in the data to others. But note that we are so good at spotting patterns, that we can find them where they don't exist. Here is an example of the "face" on Mars.
# <img src="images/face.png" />

# %% [markdown]
# Controling the `Input` and the `Output` of a Black Box. That's what we call Controlled Experiment. Sometimes choosing a subset from our experimental data could be benefitial.
# Supervised learning: <img src="images/slearning.png" />

# %% [markdown]
# **REMEMBER:** We go from data to hypothesis, not the opposite!!!!

# %% [markdown]
# Just, please, label your axes!! <img src="images/becareful.png"/>

# %% [markdown]
# And be careful with the exterpolation!
# <img src="images/exterpolation.png" />

# %% [markdown]
# ### Main Concepts in Data Visualization
# How to tell the right story...

# %% [markdown]
# **Types of plots:**
# * Histograms - show distributions
# * Boxplots - show the range and skewness of values
# * Bar charts - show how different categories compare
# * Line plots - show how one (dependent) variable varies with respect an independent variable (e.g. over time)
# * Pie charts - show relative sizes between parts of a whole
# * Simgle numbers

# %% [markdown]
# **How to know when and what to plot?** <br />
# Choosing the right plot is a matter of **intuition**. The goal is to **present the message clearly**, or "tell the right story". There are two main kinds of visualizations.
# * For scientific analysis and work - **stricter rules**
#     * For exploratory analysis / quick references
# * For presenting the results to non-specialists - we can be creative, but we have to keep our message in mind.
# * The result may also be printed or viewed on a dashboard.

# %% [markdown]
# Each plot has two spatial dimensions, but we can add more using color, size, even animation. To choose the right plot, think about numberical or categorical variables, structure (spatial, temporal, etc.), clustering, relative size and etc.

# %% [markdown]
# **How can you know what all of these are?** <br />
# Perform an **exploratory data analysis** first. Play around with the data and document everithing, so you remember it later.

# %% [markdown]
# The **basic rules** are pretty simple. First of all, choose apropriate chart type. *If you cant, just compare.* Make the plot big enough to fit the plotting area. When it's not obvious, add a title and a legent. **Label the axes.** Point at interesting data. Use marker size and color to convey information. Don't strain the reader!

# %% [markdown]
# ### Plotting Basics
# Starting out easy

# %% [markdown]
# `%matplotlib inline` is the backend. There are few more. You can check them out!

# %% [markdown]
# I have already downloaded the WHR dataset earlier, so let's just import it :d

# %%
whr_2019 = pd.read_csv("datasets/2019.csv")
whr_2018 = pd.read_csv("datasets/2018.csv")
whr_2017 = pd.read_csv("datasets/2017.csv")

# %%
whr_2019
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
whr_2019.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# 9            10           Austria  7.246           1.376           1.475
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# ...

# %%
whr_2019.describe().T
# Out:
#                               count       mean        std    min       25%  \
# Overall rank                  156.0  78.500000  45.177428  1.000  39.75000
# Score                         156.0   5.407096   1.113120  2.853   4.54450
# GDP per capita                156.0   0.905147   0.398389  0.000   0.60275
# Social support                156.0   1.208814   0.299191  0.000   1.05575
# Healthy life expectancy       156.0   0.725244   0.242124  0.000   0.54775
# Freedom to make life choices  156.0   0.392571   0.143289  0.000   0.30800
# Generosity                    156.0   0.184846   0.095254  0.000   0.10875
# Perceptions of corruption     156.0   0.110603   0.094538  0.000   0.04700
#
#                                   50%        75%      max
# Overall rank                  78.5000  117.25000  156.000
# Score                          5.3795    6.18450    7.769
# GDP per capita                 0.9600    1.23250    1.684
# Social support                 1.2715    1.45250    1.624
# ...

# %%
whr_2019.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
whr_2018
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %%
whr_2018.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
# 5             6       Netherlands  7.441           1.361           1.488
# 6             7            Canada  7.328           1.330           1.532
# 7             8       New Zealand  7.324           1.268           1.601
# 8             9            Sweden  7.314           1.355           1.501
# 9            10         Australia  7.272           1.340           1.573
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# ...

# %%
whr_2018.describe().T
# Out:
#                               count       mean        std    min       25%  \
# Overall rank                  156.0  78.500000  45.177428  1.000  39.75000
# Score                         156.0   5.375917   1.119506  2.905   4.45375
# GDP per capita                156.0   0.891449   0.391921  0.000   0.61625
# Social support                156.0   1.213237   0.302372  0.000   1.06675
# Healthy life expectancy       156.0   0.597346   0.247579  0.000   0.42225
# Freedom to make life choices  156.0   0.454506   0.162424  0.000   0.35600
# Generosity                    156.0   0.181006   0.098471  0.000   0.10950
# Perceptions of corruption     155.0   0.112000   0.096492  0.000   0.05100
#
#                                   50%        75%      max
# Overall rank                  78.5000  117.25000  156.000
# Score                          5.3780    6.16850    7.632
# GDP per capita                 0.9495    1.19775    2.096
# Social support                 1.2550    1.46300    1.644
# ...

# %%
whr_2018.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
# We could get the data like this
whr_2018["GDP per capita"]
# Out:
# 0      1.305
# 1      1.456
# 2      1.351
# 3      1.343
# 4      1.420
#        ...
# 151    0.442
# 152    0.455
# 153    0.337
# 154    0.024
# 155    0.091
# Name: GDP per capita, Length: 156, dtype: float64

# %%
# And use the .hist() function to plot it like histogram
whr_2018["GDP per capita"].hist()
# Out:
# <Axes: >

# %%
# Or, respectfully, we could do this
plt.hist(whr_2018["GDP per capita"])

plt.xlabel("GDP contribution")
plt.ylabel("Count")

plt.show()

# %%
whr_2018["GDP per capita"].mean()
# Out:
# 0.8914487179487179

# %%
# We could change the number of bins
plt.hist(whr_2018["GDP per capita"], bins = 50)

plt.xlabel("GDP contribution")
plt.ylabel("Count")

plt.show()

# %% [markdown]
# But, be carefull, though. Sometimes they become unreadable!

# %%
plt.hist(whr_2018["GDP per capita"], bins = 400)

plt.xlabel("GDP contribution")
plt.ylabel("Count")

plt.show()

# %% [markdown]
# It kind of looks like a barcode xd

# %%
# There is some data missing. We could check the gap
gpca = "GDP per capita"
whr_2018[
    (whr_2018[gpca] > 1.5) & 
    (whr_2018[gpca] < 2.0)
].sort_values(gpca)
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 33            34         Singapore  6.343           1.529           1.451
# 16            17        Luxembourg  6.910           1.576           1.520
# 31            32             Qatar  6.374           1.649           1.303
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 33                    1.008                         0.631       0.261
# 16                    0.896                         0.632       0.196
# 31                    0.748                         0.654       0.256
#
#     Perceptions of corruption
# 33                      0.457
# 16                      0.321
# 31                      0.171

# %%
whr_2019[
    (whr_2019[gpca] > 1.5) & 
    (whr_2019[gpca] < 2.0)
].sort_values(gpca)
# Out:
#     Overall rank     Country or region  Score  GDP per capita  Social support  \
# 20            21  United Arab Emirates  6.825           1.503           1.310
# 33            34             Singapore  6.262           1.572           1.463
# 13            14            Luxembourg  7.090           1.609           1.479
# 28            29                 Qatar  6.374           1.684           1.313
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 20                    0.825                         0.598       0.262
# 33                    1.141                         0.556       0.271
# 13                    1.012                         0.526       0.194
# 28                    0.871                         0.555       0.220
#
#     Perceptions of corruption
# 20                      0.182
# 33                      0.453
# 13                      0.316
# 28                      0.167

# %%
whr_2018.nsmallest(10, gpca)
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 97             98                   Somalia  4.982           0.000
# 154           155  Central African Republic  3.083           0.024
# 131           132          Congo (Kinshasa)  4.245           0.069
# 148           149                   Liberia  3.495           0.076
# 155           156                   Burundi  2.905           0.091
# 133           134                     Niger  4.166           0.131
# 146           147                    Malawi  3.587           0.186
# 122           123                Mozambique  4.417           0.198
# 112           113              Sierra Leone  4.571           0.256
# 138           139                      Togo  3.999           0.259
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 97            0.712                    0.115                         0.674
# 154           0.000                    0.010                         0.305
# ...

# %%
# Ok ok, now let's check the GDP contribution on both of the plots
plt.hist(whr_2018[gpca], bins = 15, label = "2018", alpha = 0.7)
plt.hist(whr_2019[gpca], bins = 15, label = "2019", alpha = 0.7)

plt.legend()
plt.xlabel("GDP contribution")
plt.ylabel("Count")

plt.show()

# %%
plt.hist(whr_2018["Score"], bins = 15, label = "2018", alpha = 0.7)
plt.hist(whr_2019["Score"], bins = 15, label = "2019", alpha = 0.7)

plt.legend()
plt.xlabel("Score")
plt.ylabel("Count")

plt.show()

# %%
plt.boxplot([whr_2018["Score"], whr_2019["Score"]])
plt.xticks([1, 2], ["2018", "2019"])
plt.show()

# %%
# We could merge two tables
whr_merged = whr_2018.merge(whr_2019, on = "Country or region", suffixes = ["_2018", "_2019"])

# %%
scores = whr_merged[["Country or region", "Score_2018", "Score_2019"]]

# %%
scores.nlargest(20, "Score_2018")
# Out:
#        Country or region  Score_2018  Score_2019
# 0                Finland       7.632       7.769
# 1                 Norway       7.594       7.554
# 2                Denmark       7.555       7.600
# 3                Iceland       7.495       7.494
# 4            Switzerland       7.487       7.480
# 5            Netherlands       7.441       7.488
# 6                 Canada       7.328       7.278
# 7            New Zealand       7.324       7.307
# 8                 Sweden       7.314       7.343
# 9              Australia       7.272       7.228
# 10        United Kingdom       7.190       7.054
# 11               Austria       7.139       7.246
# 12            Costa Rica       7.072       7.167
# 13               Ireland       6.977       7.021
# 14               Germany       6.965       6.985
# 15               Belgium       6.927       6.923
# 16            Luxembourg       6.910       7.090
# 17         United States       6.886       6.892
# ...

# %%
# Data Sins ???
plt.barh(scores["Country or region"], scores["Score_2018"])
plt.show()

# %%
plt.barh(scores.nlargest(20, "Score_2018")["Country or region"], scores.nlargest(20, "Score_2018")["Score_2018"])
plt.gca().invert_yaxis()
plt.show()

# %%
plt.barh(scores.nsmallest(20, "Score_2018")["Country or region"], scores.nsmallest(20, "Score_2018")["Score_2018"])
#plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# As we could see, the diapasons of the two graphs are not the same. So this way it's harder for us to compare them

# %%
plt.barh(scores.nsmallest(20, "Score_2018")["Country or region"], scores.nsmallest(20, "Score_2018")["Score_2018"])
plt.xlim(0, 8)
plt.show()

# %% [markdown]
# Also, we could change the size of the plot using `figsize`

# %%
plt.figure(figsize = (5, 10))

plt.barh(scores.nsmallest(20, "Score_2018")["Country or region"], scores.nsmallest(20, "Score_2018")["Score_2018"])
plt.xlim(0, 8)

plt.show()

# %%
# There are piecharts, too
plt.pie([1, 5, 135])
plt.show()

# %%
whr_2017
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %%
# Merge them once more...
whr_merged = whr_merged.merge(whr_2017.rename(columns = lambda col: col + "_2017"), 
                 left_on = "Country or region", right_on = "Country_2017", suffixes = ["", "_2017"])

# %%
whr_merged.columns
# Out:
# Index(['Overall rank_2018', 'Country or region', 'Score_2018',
#        'GDP per capita_2018', 'Social support_2018',
#        'Healthy life expectancy_2018', 'Freedom to make life choices_2018',
#        'Generosity_2018', 'Perceptions of corruption_2018',
#        'Overall rank_2019', 'Score_2019', 'GDP per capita_2019',
#        'Social support_2019', 'Healthy life expectancy_2019',
#        'Freedom to make life choices_2019', 'Generosity_2019',
#        'Perceptions of corruption_2019', 'Country_2017', 'Happiness.Rank_2017',
#        'Happiness.Score_2017', 'Whisker.high_2017', 'Whisker.low_2017',
#        'Economy..GDP.per.Capita._2017', 'Family_2017',
#        'Health..Life.Expectancy._2017', 'Freedom_2017', 'Generosity_2017',
#        'Trust..Government.Corruption._2017', 'Dystopia.Residual_2017'],
#       dtype='object')

# %%
whr_merged = whr_merged.rename(columns = {"Happiness.Score_2017": "Score_2017"})

# %%
scores = whr_merged[["Country or region", "Score_2017", "Score_2018", "Score_2019"]]

# %%
scores
# Out:
#             Country or region  Score_2017  Score_2018  Score_2019
# 0                     Finland       7.469       7.632       7.769
# 1                      Norway       7.537       7.594       7.554
# 2                     Denmark       7.522       7.555       7.600
# 3                     Iceland       7.504       7.495       7.494
# 4                 Switzerland       7.494       7.487       7.480
# ..                        ...         ...         ...         ...
# 142                     Yemen       3.593       3.355       3.380
# 143                  Tanzania       3.349       3.303       3.231
# 144               South Sudan       3.591       3.254       2.853
# 145  Central African Republic       2.693       3.083       3.083
# 146                   Burundi       2.905       2.905       3.775
#
# [147 rows x 4 columns]

# %%
scores[scores["Country or region"] == "Bulgaria"]
# Out:
#    Country or region  Score_2017  Score_2018  Score_2019
# 93          Bulgaria       4.714       4.933       5.011

# %%
bg_scores = scores[scores["Country or region"] == "Bulgaria"].T.drop("Country or region").values.ravel()
ro_scores = scores[scores["Country or region"] == "Romania"].T.drop("Country or region").values.ravel()
# ravel() turns values into array

# %%
bg_scores
ro_scores
# Out:
# array([5.82499980926514, 5.945, 6.07], dtype=object)

# %%
years = list(range(2017, 2020))

# %%
plt.plot(years, bg_scores, linewidth = 2, label = "BG", linestyle = "dashed")
plt.scatter(years, bg_scores, marker="s", s = 50)

plt.plot(years, ro_scores, linewidth = 2, label = "RO", linestyle = "dashed")
plt.scatter(years, ro_scores, marker="s", s = 50)

plt.title("Bulgaria and Romania: Happiness Score")

plt.xlabel("Year")
plt.ylabel("Score")
plt.legend(loc = "lower right")

plt.xticks(years)

plt.show()

# %% [markdown]
# ### Data Visualization Examples
# The good, the bad, the ugly and the WTF

# %% [markdown]
# <img src="images/comic1.png" />

# %% [markdown]
# Don't use comic sans unless you work at **CERN** :d

# %% [markdown]
# Cool website to check out: [`WTFViz`](https://viz.wtf) <br />
# Also check out: [`Data is Ugly`](https://www.reddit.com/r/dataisugly) and [`Data is Beautiful`](https://www.reddit.com/r/dataisbeautiful) <br /> Data science is art :)

# %% [markdown]
# The plot should tell a story. It should be clear what it want's to say. It should make use of temporal data, **it has labaled axes** and conveys a clear message. If it is not a scientific plot, it should be interesting for the reader. It should tell as much information as possible, while still giving the information and telling the story. The good plot should also allow comparison of different distributions. It should use a clear color map and possibly not comic sans as a font. Labels also make it easier to read. Good plot is easy on the eyes and tells the whole story, not just a part of it. Stacked area charts, or transparent ones also give us a chance to see the difference easier. Legend placement is also something to note. It shouldn't hide a part of the plot. It should not have highly skewed and disproportional elements. **DO NOT F\*\*\*\*\*G USE 3D CHARTS** Perspective often lies! The chart should be easily understandable. The values should be related. And the customizations should make sence... It should show the real purpose, and HAVE AXES!! The background should not distract the reader. There should be relation between different variables on the chart, else there will be no sense at all. The data should be right. Do not make spelling errors xd...

# %% [markdown]
# ### Customizing and Styles

# %% [markdown]
# You could set a style using `plt.style.use("{the name of the style}")`

# %%
# For example
plt.style.use("bmh")

# %% [markdown]
# To check all avaliable styles you could use the `.available` method

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# Matplotlib is customizable af. You could not just learn everything... and remember it :D That's why we have [the documentation](https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html)

# %% [markdown]
# ### Exploratory Data Analysis (EDA)
# Making sense of our data

# %% [markdown]
# Other data ploting libraries are [`Seaborn`](https://seaborn.pydata.org) and [`Bokeh`](https://docs.bokeh.org/en/latest/index.html). You could check them out. They make some pretty plots pretty easily, but have in mind that they are not as flexible as matplotlib. [`Vega-Altair`](https://altair-viz.github.io), [`GGPlot2`](https://ggplot2.tidyverse.org) and [`Plotly`](https://plotly.com/python/) are also cool options. But we need to focus on representing the data, not the actual library we use. :)

# %% [markdown]
# * Exploratory Data Analysis is a process to see what the data can tell us.
#     * Not tied to formal data modelling or hypothesis testing
# * Many people have written about this (most notably John Tukey, 1961)
# * Like data cleaning, it relies heavily on the scientist's intuition.
# * Objectives:
#     * Suggest hypotheses
#     * Assess assumptions on which models will be based
#     * Aid selection of features (feature engineering)
#     * Provide a basis for further data collections

# %% [markdown]
# Analytic Graphs are good for explainign the dataset visually. We could show distributions, relations, comparisons and casuality even in multivariate data.
#
# + Principles of analytic (scientific) graphs
#     + Show **comparisons**
#     + Show **casuality**
#         + **Correlation does not imply causation**
#     + Show **multivariatie data** (many variables)
#     + Integrate evidence from **multiple sources**
#     + Describe and **document** evidence
#     + **"Content is king"**
#         + We have to have something interesting to report
#
# These principles apply to EDA as well

# %% [markdown]
# Check out the t-distributed Stochastic Neighbor Embedding (`t-SNE`) and Uniform Manifold Approximation and Projection (`UMAP`)

# %% [markdown]
# Date: 27.06.2023
